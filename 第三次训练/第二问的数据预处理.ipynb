# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import statsmodels.api as sm
from statsmodels.multivariate.manova import MANOVA
from scipy.stats import pearsonr
mpl.rcParams["font.sans-serif"] = ["kaiti"] # 设置中文字体
mpl.rcParams["axes.unicode_minus"] = False # 设置减号不改变

# %%
D1 = pd.read_excel(r"第二问的修改数据.xlsx",index_col = 0)
data = D1.values
# 将出生日期，转化成年龄
data[:,0] = 2023-data[:,0].copy()
# 将年龄进行分段
data[data[:,0]>65,0]=-4
data[data[:,0]>45,0]=-3
data[data[:,0]>18,0]=-2
data[data[:,0]>=0,0]=-1
data[:,0] = -data[:,0].copy()
print("0-18岁居民有:",np.sum(data[:,0]==1))
print("18-45岁居民有:",np.sum(data[:,0]==2))
print("45-65岁居民有:",np.sum(data[:,0]==3))
print("65+岁居民有:",np.sum(data[:,0]==4))
idx = D1.columns.values.copy()
idx.astype(np.str_)
for i in range(5,idx.shape[0]-2-7,3):
    idx[i+2] = idx[i][3:]+idx[i+2][:-2] if i>5 else idx[i][3:]+idx[i+2]
x= data[:,5:data.shape[1]-7]
y= data[:,0]
md1 = MANOVA(x,y)
print(md1.mv_test().results["x0"]["stat"])
# 对不同性别的居民在饮食习惯上进行方差检验
x= data[:,5:data.shape[1]-7]
y= data[:,1]
md1 = MANOVA(x,y)
print(md1.mv_test().results["x0"]["stat"])
x= data[:,5:data.shape[1]-7]
y= data[:,2]
md1 = MANOVA(x,y)
print(md1.mv_test())
x= data[:,5:data.shape[1]-7]
y= data[:,3]
md1 = MANOVA(x,y)
print(md1.mv_test())
x= data[:,5:data.shape[1]-7]
y= data[:,4]
md1 = MANOVA(x,y)
print(md1.mv_test())

# %%
svm = []
c = np.zeros((5,81))
for i in range(0,5):
    k = 0
    for j in range(5,data.shape[1]-7):
        x = data[:,i]
        y = data[:,j]
        # 执行 Pearson 相关性分析
        correlation_coefficient, p_value = pearsonr(x,y)
        alpha = 0.05 # 显著水平
        if p_value < alpha:
            print("在显著性水平 {} 下，[{}]和[{}]之间的相关性是显著的。".format(alpha,idx[i],idx[j]))
            svm += ["在显著性水平 {} 下，[{}]和[{}]之间的相关性是显著的。".format(alpha,idx[i],idx[j])]
        else:
            print("在显著性水平 {} 下，[{}]和[{}]之间的相关性不显著。".format(alpha,idx[i],idx[j]))
        c[i,k]=round(correlation_coefficient,4)
        k+=1
svm
# Out:
# 在显著性水平 0.05 下，[出生年]和[是否吃大米]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[食用大米的频率]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[大米平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃小麦面粉]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用小麦面粉的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[小麦面粉平均每次食用量]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[是否吃杂粮]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[食用杂粮的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[杂粮平均每次食用量]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[是否吃薯类]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[食用薯类的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[薯类平均每次食用量]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[是否吃油炸面食]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用油炸面食的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[油炸面食平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃猪肉]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[食用猪肉的频率]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[猪肉平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃牛羊肉]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用牛羊肉的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[牛羊肉平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃禽肉]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用禽肉的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[禽肉平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃内脏类]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用内脏的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[内脏类平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃水产类]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[食用水产的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[水产类平均每次食用量]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃鲜奶]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用鲜奶的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[鲜奶平均每次食用量.]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃奶粉]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用奶粉的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[奶粉平均每次食用量.]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃酸奶]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用酸奶的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[酸奶平均每次食用量.]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃蛋类]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用蛋类的频率]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[蛋类平均每次食用量.]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[是否吃豆腐]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用豆腐的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[豆腐平均每次食用量.]之间的相关性不显著。
# 在显著性水平 0.05 下，[出生年]和[是否吃豆腐丝等]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和[食用豆腐丝等的频率]之间的相关性是显著的。
# 在显著性水平 0.05 下，[出生年]和
�的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[牛羊肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃禽肉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用禽肉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[禽肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃内脏类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用内脏的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[内脏类平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃水产类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用水产的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[水产类平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃鲜奶]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用鲜奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃奶粉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用奶粉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[奶粉平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃酸奶]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用酸奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[酸奶平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃蛋类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[蛋类平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[豆腐平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃豆浆]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用豆浆的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[豆浆平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃干豆]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用干豆的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[干豆平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[新鲜蔬菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃海草类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用咸菜的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用酸菜的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[酸菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃糕点]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用糕点的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃水果]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用水果的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃果汁饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用果汁饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[果汁饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[是否吃其他饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[食用其他饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[性别]和[其他饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用大米的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃小麦面粉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用小麦面粉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[小麦面粉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃杂粮]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用杂粮的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[杂粮平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃薯类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用薯类的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[薯类平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃油炸面食]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用油炸面食的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[油炸面食平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用猪肉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃牛羊肉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用牛羊肉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[牛羊肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用禽肉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃内脏类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[内脏类平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃水产类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用水产的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[水产类平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃鲜奶]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用鲜奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[鲜奶平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃酸奶]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用酸奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[酸奶平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃蛋类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用蛋类的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[蛋类平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃豆腐]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用豆腐的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[豆腐平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃豆腐丝等]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用豆腐丝等的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[豆腐丝等平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃豆浆]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用豆浆的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[豆浆平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃新鲜蔬菜]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用新鲜蔬菜的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[新鲜蔬菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃海草类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用海草的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[海草类平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃咸菜]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[咸菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃泡菜]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用泡菜的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[泡菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用酸菜的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[酸菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃糕点]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用糕点的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[糕点平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃水果]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用水果的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[水果平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃果汁饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用果汁饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[果汁饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[是否吃其他饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[食用其他饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[文化程度]和[其他饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[大米平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃小麦面粉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用小麦面粉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[小麦面粉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用杂粮的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃薯类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃油炸面食]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用油炸面食的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[油炸面食平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用猪肉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[猪肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃牛羊肉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用牛羊肉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[牛羊肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[禽肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃鲜奶]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用鲜奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃奶粉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用奶粉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[奶粉平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃酸奶]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用酸奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[酸奶平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[蛋类平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃豆腐]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用豆腐的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[豆腐平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃干豆]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[新鲜蔬菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃糕点]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[糕点平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃果汁饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用果汁饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[果汁饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[是否吃其他饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[食用其他饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[婚姻状况]和[其他饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[大米平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用小麦面粉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃杂粮]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用杂粮的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用薯类的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃油炸面食]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用油炸面食的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[油炸面食平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃猪肉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[猪肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃牛羊肉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[牛羊肉平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃禽肉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃内脏类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[内脏类平均每次食用量]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用水产的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用鲜奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃奶粉]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用奶粉的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[奶粉平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用酸奶的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃蛋类]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用蛋类的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[蛋类平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃豆腐]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用豆腐的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃豆浆]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用豆浆的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[豆浆平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[咸菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃泡菜]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[泡菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃酸菜]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用酸菜的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[酸菜平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃糕点]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用糕点的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用水果的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃果汁饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[果汁饮料平均每次食用量.]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[是否吃其他饮料]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[食用其他饮料的频率]之间的相关性是显著的。',
#  '在显著性水平 0.05 下，[职业]和[其他饮料平均每次食用量.]之间的相关性是显著的。']

# %%
for j in range(0,81-5,5):
    try:
        plt.figure(figsize = (6,6))
        plt.imshow(c[:,j:j+5],cmap="Paired",vmin=-0.15,vmax=0.15)
        plt.xticks([0,1,2,3,4],idx[5:86][j:j+5],rotation=30)
        plt.yticks([0,1,2,3,4],idx[:5],rotation=0)
        plt.colorbar(fraction=0.046, pad=0.04,shrink=0.5)
        plt.show()
    except:pass
